# %% [markdown]
# # Actor Criticを実装する

# %%
from pathlib import Path
import math
import numpy as np
import pandas as pd
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical
import matplotlib.pyplot as plt
import seaborn as sns
import settings

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## パラメターの設定

# %%
gym_game_name = 'CartPole-v1'

# %%
model_dir_path = Path('mdoel')
result_dir_path = Path('result')
if not model_dir_path.exists():
    model_dir_path.mkdir()
if not result_dir_path.exists():
    result_dir_path.mkdir()

# %% [markdown]
# ## モデルの構築

# %%
class Policy(nn.Module):

    def __init__(self):
        super(Policy, self).__init__()
        
        self.affine = nn.Linear(4, 128)

        self.action_head = nn.Linear(128, 2)
        self.value_head = nn.Linear(128, 1)

        self.saved_actions = []
        self.saved_rewards = []

    def forward(self, x):
        
        x = F.relu(self.affine(x))

        action_prob = F.softmax(self.action_head(x), dim=-1)
        state_values = self.value_head(x)

        return action_prob, state_values

# %%
def select_action(model, state, device):

    state = torch.from_numpy(state).float()
    probs, state_value = model(state.to(device))

    m = Categorical(probs)
    action = m.sample()
    model.saved_actions.append((m.log_prob(action), state_value))

    return action.item(), state_value

# %%
def learn_model(model, gamma, optimizer, device):

    R = 0
    returns = []
    for r in model.saved_rewards[::-1]:
        R = r + gamma * R
        returns.insert(0, R)

    returns = torch.tensor(returns)
    returns = (returns - returns.mean()) / (returns.std() + 1e-06)

    policy_losses = []
    value_losses = []
    for (log_prob, value), R in zip(model.saved_actions, returns):
        advantage = R - value.item()
        policy_losses.append(-log_prob * advantage)
        value_losses.append(F.smooth_l1_loss(value, torch.tensor([R]).to(device)))

    loss = torch.stack(policy_losses).sum() + torch.stack(value_losses).sum()
     
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    del model.saved_rewards[:]
    del model.saved_actions[:]

    return loss

# %% [markdown]
# ## モデルの学習

# %%
env = gym.make(gym_game_name)
env.reset(seed=settings.seed)
torch.manual_seed(settings.seed)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
model = Policy()
model = model.to(device)
optimizer = optim.Adam(model.parameters(), lr=3e-2)
eps = np.finfo(np.float32).eps.item()

reward_result = []
reward_displays = []
loss_result = []
loss_display = []
for episode in range(1, settings.epochs + 1):

    state = env.reset()
    episode_reward = 0
    for t in range(1, 10000):

        action, _ = select_action(model=model, state=state, device=device)
        state, reward, done, _ = env.step(action)

        if settings.flag_env_render:
            env.render()

        model.saved_rewards.append(reward)
        episode_reward += reward
        if done:
            break

    reward_displays.append(episode_reward)

    loss = learn_model(model=model, gamma=settings.gamma, optimizer=optimizer, device=device)
    loss = loss.detach().item()
    loss_display.append(loss)

    reward_result.append(episode_reward)
    loss_result.append(loss)

    if env.spec.max_episode_steps == np.mean(reward_displays):
        print('Game Win !!')
        break

    if episode % settings.display_loop == 0:
        print('[{}/{}]\tMean Loss: {:.2f}\tMean Reward: {:.0f}'.format(
            episode, settings.epochs, np.mean(loss_display), np.mean(reward_displays)
        ))
        reward_displays = []
        loss_display = []


model = model.to('cpu')
torch.save(model.state_dict(), model_dir_path.joinpath('actor_critic.pth'))

result = pd.DataFrame({
    'episode': np.arange(1, len(reward_result) + 1),
    'reward': reward_result,
    'loss': loss_result
})
result.to_csv(result_dir_path.joinpath(f'actor_critic_result_{gym_game_name}.csv'), index=False)
# Out:
# 2022-06-03 08:26:14.842 Python[65297:8463180] ApplePersistenceIgnoreState: Existing state will not be touched. New state will be written to /var/folders
# Episode 420	Mean Loss: 2.85	Mean Reward: 131
# Episode 430	Mean Loss: 3.23	Mean Reward: 166
# Episode 440	Mean Loss: -0.65	Mean Reward: 230
# Episode 450	Mean Loss: 19.90	Mean Reward: 194
# Episode 460	Mean Loss: 5.37	Mean Reward: 176
# Episode 470	Mean Loss: 9.19	Mean Reward: 160
# Episode 480	Mean Loss: 2.67	Mean Reward: 158
# Episode 490	Mean Loss: 2.49	Mean Reward: 149
# Episode 500	Mean Loss: 3.23	Mean Reward: 162
# Episode 510	Mean Loss: 1.78	Mean Reward: 187
# Episode 520	Mean Loss: 6.28	Mean Reward: 217
# Episode 530	Mean Loss: 13.07	Mean Reward: 243
# Episode 540	Mean Loss: 27.82	Mean Reward: 325
# Episode 550	Mean Loss: 34.97	Mean Reward: 277
# Episode 560	Mean Loss: 15.18	Mean Reward: 48
# Episode 570	Mean Loss: 27.41	Mean Reward: 117
# Episode 580	Mean Loss: 70.26	Mean Reward: 257
# Game Win !!

# %% [markdown]
# ## モデルの検証

# %% [markdown]
# ### 学習時の報酬の推移

# %%
result_data = pd.read_csv(result_dir_path.joinpath(f'actor_critic_result_{gym_game_name}.csv'))

# %%
fig = plt.figure(figsize=(12, 6), facecolor='white')

ax = fig.add_subplot(1, 2, 1)
g = sns.lineplot(
    data=result_data,
    x='episode', y='reward',
    ax=ax
)
plt.title('報酬の推移', fontsize=18, weight='bold')
plt.ylabel('')

ax = fig.add_subplot(1, 2, 2)
g = sns.lineplot(
    data=result_data.assign(group=lambda x: x.episode.map(lambda y: math.floor((y - 1) / 10))),
    x='group', y='reward',
    ax=ax
)
plt.title('10エピソードごとの報酬平均値の推移', fontsize=18, weight='bold')
plt.ylabel('')

plt.tight_layout()
plt.savefig(result_dir_path.joinpath(f'actor_critic_learning_reward_{gym_game_name}.png'), dpi=300)

# %% [markdown]
# ### 学習済みモデルの獲得報酬の分布

# %%
model = Policy()
model.load_state_dict(torch.load(model_dir_path.joinpath('actor_critic.pth')))
model.eval()
# Out:
# Policy(
#   (affine): Linear(in_features=4, out_features=128, bias=True)
#   (action_head): Linear(in_features=128, out_features=2, bias=True)
#   (value_head): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
def select_action_valid(model, state, device):

    with torch.no_grad():
        state = torch.from_numpy(state).float()
        probs, state_value = model(state.to(device))

    return probs.argmax().item(), state_value

# %%
state = env.reset()
episode_reward = 0
done = False
while not done:

    action, state_value = select_action_valid(model=model, state=state, device=device)
    state, reward, done, _ = env.step(action)

    env.render()
    episode_reward += reward

print('Game End Reward: {:.0f}'.format(episode_reward))
# Out:
# Game End Reward: 500
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
